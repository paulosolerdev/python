# %% [markdown]
# # 1. Classes e Objetos

# %%
class Livro:

    def __init__(self, titulo, autor, ano):

        self.titulo = titulo
        self.autor = autor
        self.ano = ano

    
meu_livro = Livro("1984", "Geoge Orwell", 1949)

# %% [markdown]
# # 2. Atributos

# %%
print(meu_livro.titulo)
print(meu_livro.autor)
print(meu_livro.ano)

print()

# %% [markdown]
# # 3. Métodos

# %%
class Livro:

    def __init__(self, titulo, autor, ano):

        self.titulo = titulo
        self.autor = autor
        self.ano = ano

    def descricao(self):

        return f"'{self.titulo}' por {self.autor}, publicado em {self.ano}."
    
meu_livro = Livro("1984", "Geoge Orwell", 1949)

print(meu_livro.descricao())

# %% [markdown]
# ## 2. Conceitos Básicos
#
#     Classes e Objetos: Definindo e instanciando classes.

# %%
# Vamos começar com um exemplo simples de uma classe chamada
# Carro. Esta classe irá representar um carro genérico e terá
# algumas propriedades.

class Carro:

    def __init__(self, marca, modelo, cor):

        self.marca = marca
        self.modelo = modelo
        self.cor = cor
        self.velocidade = 0

    def acelerar(self):

        self.velocidade += 10

        print(f'Velocidade atual: {self.velocidade} km/h')

    def frear(self):

        if self.velocidade > 0:

            self.velocidade -= 10

            print(f'Velocidade atual: {self.velocidade} km/h')

        else:

            print('O carro está parado')
            
    def exibir_info(self):

        print(f'Marca: {self.marca}, Modelo: {self.modelo}, Cor: {self.cor}')

carro1 = Carro('Toyota', 'Corolla', 'Branco')

carro2 = Carro('Ford', 'Fusion', 'Preto')

carro1.exibir_info()

carro1.acelerar()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.frear()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.acelerar()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.acelerar()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()

print()

carro2.exibir_info()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()

# %%
class Carro:

    def __init__(self, marca, modelo, cor):

        self.marca = marca
        self.modelo = modelo
        self.cor = cor
        self.velocidade = 0

    def acelerar(self):

        self.velocidade += 10

        print(f'Velocidade atual: {self.velocidade} km/h')

    def frear(self):

        if self.velocidade > 0:

            self.velocidade -= 10

            print(f'Velocidade atual: {self.velocidade} km/h')

        else:

            print('O carro está parado')
            
    def exibir_info(self):

        print(f'Marca: {self.marca}, Modelo: {self.modelo}, Cor: {self.cor}')

lista_carros = []

while True:

    print('\n--- Menu ---')
    print('1. Adicionar novo carro')
    print('2. Exibir informações dos carros')
    print('3. Acelerar um carro')
    print('4. Frear um carro')
    print('5. Sair')

    opcao = input('Escolha uma opção: ')
    
    if opcao == '1':

        marca = input('Digite a marca do carro: ')
        modelo = input('Digite o modelo do carro: ')
        cor = input('Digite a cor do carro: ')

        carro = Carro(marca, modelo, cor)

        lista_carros.append(carro)

    elif opcao == '2':

        if lista_carros:

            for carro in lista_carros:

                carro.exibir_info()

        else:
            
            print('Nenhum carro cadastrado')

    elif opcao == '3':

        modelo = input('Digite o modelo do carro que você deseja acelerar:  ')

        for carro in lista_carros:

            if carro.modelo == modelo:
                
                carro.acelerar()

                break

            else:
                
                print(f'Carro {modelo} não encontrado')

    elif opcao == '4':

        modelo = input('Digite o modelo do carro que você deseja frear: ')

        for carro in lista_carros:

            if carro.modelo == modelo:
                
                carro.frear()

                break
                
    elif opcao == '5':

        print('Saindo do programa...')

        break

    else:

        print('Opção inválida')

# %% [markdown]
# ## 2. Conceitos Básicos
#
#     Atributos: Definindo e acessando atributos de uma classe.

# %%
# Exemplo Prático: Gerenciamento de Jogadores de Futebol

# Descrição:
# Imagine que você está desenvolvendo um software simples para gerenciar
# jogadores em um time de futebol. Cada jogador tem um nome, posição, 
# número da camisa e quantidade de gols marcados na temporada.

# 1. Definição da Classe Jogador:

class Jogador:

    def __init__(self, nome, posicao, numero_camisa, gols_marcados=0):

        self.nome = nome
        self.posicao = posicao
        self.numero_camisa = numero_camisa
        self.gols_marcados = gols_marcados


# 2. Instanciando e Acessando Atributos:

# Instanciando jogadores

jogador1 = Jogador('Cristiano Ronaldo', 'Atacante', 7)

jogador2 = Jogador('Lionel Messi', 'Atacante', 10)

jogador3 = Jogador('Neymar Jr.', 'Atacante', 10)

# Acessando atributos

print(f'{jogador1.nome} é um {jogador1.posicao} e usa a camisa número {jogador1.numero_camisa}')

print(f'{jogador2.nome} é um {jogador2.posicao} e usa a camisa número {jogador2.numero_camisa}')

print(f'{jogador3.nome} é um {jogador3.posicao} e usa a camisa número {jogador3.numero_camisa}')

jogador1.gols_marcados +=1
jogador1.gols_marcados +=1
jogador1.gols_marcados +=1
jogador1.gols_marcados +=1
jogador1.gols_marcados +=1


print(f'{jogador1.nome} marcou {jogador1.gols_marcados}.')
# Out:
# Cristiano Ronaldo é um Atacante e usa a camisa número 7
# Lionel Messi é um Atacante e usa a camisa número 10
# Neymar Jr. é um Atacante e usa a camisa número 10
# Cristiano Ronaldo marcou 5.

# %%
"""
Objetivos:

    1. Definir uma classe chamada Fruta.
    2. Instanciar um ou mais objetos desta classe.
    3. Acessar e exibir atributos dos objetos.

Instruções:

    1. Crie uma classe chamada Fruta com os seguintes atributos:
        - nome: o nome da fruta (ex: "Maçã", "Banana").
        - preco_por_kg: o preço da fruta por quilograma.
        - quantidade_em_estoque: a quantidade da fruta em estoque (em quilogramas).

    2. Instancie pelo menos duas frutas diferentes, fornecendo valores específicos
    para seus atributos.

    3. Acesse os atributos das frutas instanciadas e exiba suas informações 
    de forma organizada, como:

        Nome da Fruta: [nome da fruta]
        Preço por Kg: [preço por kg]
        Quantidade em Estoque: [quantidade em estoque]
"""

# Solução:

class Fruta:

    def __init__(self, nome, preco_por_kg, quantidade_em_estoque):

        self.nome = nome
        self.preco_por_kg = preco_por_kg
        self.quantidade_em_estoque = quantidade_em_estoque

    def exibir_info(self):

        print(f'Nome da Fruta: {self.nome}')
        print(f'Preço por Kg: {self.preco_por_kg}')
        print(f'Quantidade em Estoque: {self.quantidade_em_estoque}')

maca = Fruta('Maçã', 2.5, 10)
banana = Fruta('Banana', 1.5, 15)

maca.exibir_info()
print('----------------')
banana.exibir_info()
# Out:
# Nome da Fruta: Maçã
# Preço por Kg: 2.5
# Quantidade em Estoque: 10
# ----------------
# Nome da Fruta: Banana
# Preço por Kg: 1.5
# Quantidade em Estoque: 15

# %%
"""
Exercício Simulando a Rotina de uma Pessoa

Objetivo:
Neste exercício, você irá implementar uma classe chamada Pessoa que simula
algumas atividades do dia a dia de um indivíduo. A classe deve conter métodos
que representem diferentes ações, como acordar, comer, dirigir, e dormir.

Além disso, a classe deve manter o controle dos estados do indivíduo para evitar
ações incompatíveis (por exemplo, não se pode dirigir enquanto come). 

Requisitos:

    1. A classe deve ter um construtor que aceite o nome da pessoa como parâmetro
    e inicialize os estados "acordado", "comendo" e "dirigindo" como False.

    2. Implemente métodos para as seguintes ações:
        - acordar(): Define o estado "acordado" como True.
        - comer(): Define o estado "comendo" como True, desde que a pessoa esteja acordada.
        - parar_de_comer(): Define o estado "comendo" como False.
        - dirigir(): Define o estado "dirigindo" como True, desde que a pessoa esteja acordada e não esteja comendo.
        - parar_de_dirigir(): Define o estado "dirigindo" como False.
        - dormir(): Define o estado "acordado" como False.

    3. Cada método deve imprimir mensagens adequadas para indicar o que a pessoa
    está fazendo ou porque não pode fazer algo.

    4. Teste a classe criando um objeto e chamando vários métodos em 
    sequência para simular uma rotina diária.
"""

# Solução:

class Pessoa:

    def __init__(self, nome):

        self.nome = nome
        self.acordado = False
        self.comendo = False
        self.dirigindo = False
    
    
    def acordar(self):

        if self.acordado:

            print(f'{self.nome} já está acordado.')

        else:

            self.acordado = True

            print(f'{self.nome} acordou.')



    def comer(self):

        if self.dirigindo:

            print(f'{self.nome} não pode comer enquanto dirige.')

        elif not self.acordado:

            print(f'{self.nome} não pode comer enquanto está dormindo.')

        elif self.comendo:

            print(f'{self.nome} já está comendo.')

        else:

            self.comendo = True

            print(f'{self.nome} começou a comer.')
        

    def parar_de_comer(self):

        if not self.comendo:

            print(f'{self.nome} não está comendo.')

        else:

            self.comendo = False

            print(f'{self.nome} parou de comer.')

    def dirigir(self):

        if not self.acordado:

            print(f'{self.nome} não pode dirigir enquanto está dormindo.')

        elif self.comendo:

            print(f'{self.nome} não pode dirigir enquanto está comendo.')

        elif self.dirigindo:

            print(f'{self.nome} já está dirigindo.')

        else:

            self.dirigindo = True

            print(f'{self.nome} começou a dirigir.')


    def parar_de_dirigir(self):

        if not self.dirigindo:

            print(f'{self.nome} não está dirigindo.')

        else:

            self.dirigindo = False

            print(f'{self.nome} parou de dirigir.')


    def dormir(self):

        if self.dirigindo or self.comendo:

            print(f'{self.nome} não pode dormir enquanto está dirigindo ou comendo.')

        elif not self.acordado:

            print(f'{self.nome} já está dormindo.')

        else:

            self.acordado = False

            print(f'{self.nome} foi dormir.')


joao = Pessoa("João")

joao.acordar()
joao.acordar()

joao.comer()
joao.comer()

joao.parar_de_comer()
joao.parar_de_comer()

joao.dirigir()
joao.dirigir()

joao.parar_de_dirigir()
joao.parar_de_dirigir()

joao.dormir()
joao.dormir()

joao.comer()
joao.dirigir()

joao.acordar()
joao.comer()
joao.dirigir()
joao.dormir()

joao.parar_de_comer()
joao.parar_de_dirigir()
# Out:
# João acordou.
# João já está acordado.
# João começou a comer.
# João já está comendo.
# João parou de comer.
# João não está comendo.
# João começou a dirigir.
# João já está dirigindo.
# João parou de dirigir.
# João não está dirigindo.
# João foi dormir.
# João já está dormindo.
# João não pode comer enquanto está dormindo.
# João não pode dirigir enquanto está dormindo.
# João acordou.
# João começou a comer.
# João não pode dirigir enquanto está comendo.
# João não pode dormir enquanto está dirigindo ou comendo.
# João parou de comer.
# João não está dirigindo.
