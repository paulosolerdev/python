# %%
# 1. Classes e Objetos

class Livro:

    def __init__(self, titulo, autor, ano):

        self.titulo = titulo
        self.autor = autor
        self.ano = ano

    
meu_livro = Livro("1984", "Geoge Orwell", 1949)


# 2. Atributos

print(meu_livro.titulo)
print(meu_livro.autor)
print(meu_livro.ano)

print()

# 3. Métodos

class Livro:

    def __init__(self, titulo, autor, ano):

        self.titulo = titulo
        self.autor = autor
        self.ano = ano

    def descricao(self):

        return f"'{self.titulo}' por {self.autor}, publicado em {self.ano}."
    
meu_livro = Livro("1984", "Geoge Orwell", 1949)

print(meu_livro.descricao())
# Out:
# 1984
# Geoge Orwell
# 1949
#
# '1984' por Geoge Orwell, publicado em 1949.

# %%
"""
2. Conceitos Básicos

    Classes e Objetos: Definindo e instanciando classes.

"""

# Vamos começar com um exemplo simples de uma classe chamada
# Carro. Esta classe irá representar um carro genérico e terá
# algumas propriedades.

class Carro:

    def __init__(self, marca, modelo, cor):

        self.marca = marca
        self.modelo = modelo
        self.cor = cor
        self.velocidade = 0

    def acelerar(self):

        self.velocidade += 10

        print(f'Velocidade atual: {self.velocidade} km/h')

    def frear(self):

        if self.velocidade > 0:

            self.velocidade -= 10

            print(f'Velocidade atual: {self.velocidade} km/h')

        else:

            print('O carro está parado')
            
    def exibir_info(self):

        print(f'Marca: {self.marca}, Modelo: {self.modelo}, Cor: {self.cor}')

carro1 = Carro('Toyota', 'Corolla', 'Branco')

carro2 = Carro('Ford', 'Fusion', 'Preto')

carro1.exibir_info()

carro1.acelerar()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.frear()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.acelerar()
carro1.acelerar()
carro1.acelerar()
carro1.frear()
carro1.acelerar()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()
carro1.frear()

print()

carro2.exibir_info()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
carro2.acelerar()
# Out:
# Marca: Toyota, Modelo: Corolla, Cor: Branco
# Velocidade atual: 10 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 30 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 10 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 30 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 30 km/h
# Velocidade atual: 40 km/h
# Velocidade atual: 50 km/h
# Velocidade atual: 40 km/h
# Velocidade atual: 50 km/h
# Velocidade atual: 40 km/h
# Velocidade atual: 30 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 10 km/h
# Velocidade atual: 0 km/h
# O carro está parado
#
# Marca: Ford, Modelo: Fusion, Cor: Preto
# Velocidade atual: 10 km/h
# Velocidade atual: 20 km/h
# Velocidade atual: 30 km/h
# Velocidade atual: 40 km/h
# Velocidade atual: 50 km/h
# Velocidade atual: 60 km/h
# Velocidade atual: 70 km/h
# Velocidade atual: 80 km/h
# Velocidade atual: 90 km/h
# Velocidade atual: 100 km/h
# Velocidade atual: 110 km/h

# %%
class Carro:

    def __init__(self, marca, modelo, cor):

        self.marca = marca
        self.modelo = modelo
        self.cor = cor
        self.velocidade = 0

    def acelerar(self):

        self.velocidade += 10

        print(f'Velocidade atual: {self.velocidade} km/h')

    def frear(self):

        if self.velocidade > 0:

            self.velocidade -= 10

            print(f'Velocidade atual: {self.velocidade} km/h')

        else:

            print('O carro está parado')
            
    def exibir_info(self):

        print(f'Marca: {self.marca}, Modelo: {self.modelo}, Cor: {self.cor}')

lista_carros = []

while True:

    print('\n--- Menu ---')
    print('1. Adicionar novo carro')
    print('2. Exibir informações dos carros')
    print('3. Acelerar um carro')
    print('4. Frear um carro')
    print('5. Sair')

    opcao = input('Escolha uma opção: ')
    
    if opcao == '1':

        marca = input('Digite a marca do carro: ')
        modelo = input('Digite o modelo do carro: ')
        cor = input('Digite a cor do carro: ')

        carro = Carro(marca, modelo, cor)

        lista_carros.append(carro)

    elif opcao == '2':

        if lista_carros:

            for carro in lista_carros:

                carro.exibir_info()

        else:
            
            print('Nenhum carro cadastrado')

    elif opcao == '3':

        modelo = input('Digite o modelo do carro que você deseja acelerar:  ')

        for carro in lista_carros:

            if carro.modelo == modelo:
                
                carro.acelerar()

                break

            else:
                
                print(f'Carro {modelo} não encontrado')

    elif opcao == '4':

        modelo = input('Digite o modelo do carro que você deseja frear: ')

        for carro in lista_carros:

            if carro.modelo == modelo:
                
                carro.frear()

                break
                
    elif opcao == '5':

        print('Saindo do programa...')

        break

    else:

        print('Opção inválida')
# Out:
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
#
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
# Marca: Toyota, Modelo: Corolla, Cor: Branco
#
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
#
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
# Marca: Toyota, Modelo: Corolla, Cor: Branco
# Marca: Honda, Modelo: Civic, Cor: Azul
#
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
# Marca: Toyota, Modelo: Corolla, Cor: Branco
# Marca: Honda, Modelo: Civic, Cor: Azul
#
# --- Menu ---
# 1. Adicionar novo carro
# 2. Exibir informações dos carros
# 3. Acelerar um carro
# 4. Frear um carro
# 5. Sair
# Saindo do programa...
