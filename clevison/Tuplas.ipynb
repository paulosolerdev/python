# %%
"""
Tuplas:

"""
print()

# %%
"""
Definição de Tuplas:
        Tuplas são umas das estruturas de dados embutidas no Python. São 
        similares às listas, mas são imutáveis, o que significa que uma
        vez definidas, os elementos não podem ser modificados.
"""

"""
Exemplo Prático: Informações de um Livro

Suponha que você esteja criando um sistema para uma biblioteca. Uma das
tarefas é representar informações sobre um livro. Você pode escolher
tuplas para representar essas informações porque, uma vez que um livro
é adicionado ao sistema, certas informações sobre ele, como o título, autor 
e ISBN, geralmente não mudam.

Portanto, para um livro com um título 'A Arte da Guerra', autor 'Sun Tzu'
e ISBN '978-8572835080', você pode representar essas informações como uma
tupla:
"""

livro = ('A Arte da Guerra', 'Sun Tzu', '978-8572835080')

titulo = livro[0]
autor = livro[1]
isbn = livro[2]

print(titulo)
print(autor)
print(isbn)
# Out:
# A Arte da Guerra
# Sun Tzu
# 978-8572835080

# %%
"""
Criação de Tuplas:
        Como criar uma tupla usando parênteses: t = (1, 2, 3)
        Tupla com um único elemento: t = (1,)
        Tupla sem parênteses: t = 1, 2, 3
        Uso da função tuple(): t = tuple([1, 2, 3])
"""

# 1. Como criar uma tupla usando parênteses

destino = ('Paris', 'França', 5)
print(destino)

#2. Tupla com um único elemento:

destino_indefinido = ('Kyoto',)
print(destino_indefinido)

#3. Tupla sem parênteses

destino2 = 'Roma', 'Itália', 4
print(destino2)

#4. Uso da função tuple()

lista_destinos_EUA = ['Nova Iorque', 'EUA', 7]
destino3 = tuple(lista_destinos_EUA)
print(destino3)
# Out:
# ('Paris', 'França', 5)
# ('Kyoto',)
# ('Roma', 'Itália', 4)
# ('Nova Iorque', 'EUA', 7)

# %%
"""
Exercício: Armazenando Informações sobre livros

Concexto: Você administra uma pequena biblioteca e decide armazenar
informações sobre seus livros usando tuplas para garantir que os dados
sejam consistentes e imutáveis.

Objetivo: Crie tuplas para representar informações de livros usando diferentes
métodos de criação de tuplas.

Instruções:
        
    
"""

"""
1. Criar uma tupla usando parênteses:
        Crie uma tupla chamada livro1 para armazenar informações sobre
        um livro: título, autor e ano de publicação.
        Use a seguinte informação: 'Orgulho e Preconceito', 'Jane Austen', 1813.
"""     

livro1 = ('Orgulho e Preconceito', 'Jane Austen', 1813)
print(livro1)

"""
2. Tupla com um único elemento:
        Você recebeu uma doação de um livro, mas só sabe o título por
        enquanto. Crie uma tupla chamada livro_indefinido com apenas
        o título: 'O Pequeno Príncipe'
"""
livro_indefinido = 'O Pequeno Príncipe',
print(livro_indefinido)

"""
3. Tupla sem parênteses:
    Para o próximo livro, use uma sintaxe siplificada. Crie uma tupla
    chamada livro2 para armazenar: '1984', 'George Orwell', 1949.
"""
livro2 = '1984', 'George Orwell', 1949
print(livro2)

"""
4. Uso da função tuple():
    Você tem uma lista de informações sobre um novo livro. Converta esta lista
    em uma tupla para garantir sua imutabilidade.
    
    A lista é: ['O Senhor dos Anéis', 'J. R. R. Tolkien', 1954]. Nomeie a tupla
    como livro3.
"""
livro3 = ['O Senhor dos Anéis', 'J. R. R. Tolkien', 1954]
livro3_tupla = tuple(livro3)
print(livro3_tupla)
# Out:
# ('Orgulho e Preconceito', 'Jane Austen', 1813)
# ('O Pequeno Príncipe',)
# ('1984', 'George Orwell', 1949)
# ('O Senhor dos Anéis', 'J. R. R. Tolkien', 1954)

# %%
"""
Acesso aos Elementos:
"""
#1. Como acessar elementos usando índices: t[0]

contato = ('João Silva', '123-456-7890', 'joao.silva@email.com')

nome = contato[0]
print(f"Nome: {nome}")

telefone = contato[1]
print(f'Telefone: {telefone}')
      
#2. Fatiamento de tuplas: t[1:3]

info_relevantes = contato[:2]

print(f'Informações Relevantes: {info_relevantes}')
# Out:
# Nome: João Silva
# Telefone: 123-456-7890
# Informações Relevantes: ('João Silva', '123-456-7890')

# %%
"""
Exercício: Gerenciamento Inventário de Produtos

Contexto: Você trabalha em um depósito e possui um inventário de 
produtos armazenados em tuplas. Cada tupla contém o nome do produto, a
quantidade em estoque e o preço unitário. Sua tarefa é acessar e exibir
certas informações desses produtos.

Objetivo: Acesse e exiba informações específicas dos produtos usando
índices e fatiamento de tuplas.

Instruções:
    
    Definindo um Produto:
        Comece definindo uma tupla chamada produto com as seguintes
        informações: 'Laptop', 10 (quantidade em estoque), 1500.00 (
        preço em dólares).
        
    Acessando elementos usando índices:
        Exiba o nome do produto.
        Em seguida, exiba a quantidade em estoque.
        
    Fatiamento de tuplas:
        Mostre as informações excluindo o preço (ou seja, nome e quantidade
        em estoque) usando fatiamento de tuplas.
        
Questões:

a) Qual o nome do produto?

b) Quantos itens desse produto estão em estoque?

c) Sem mostrar o preço, quais são as informações disponíveis sobre o
produto?

Este exercício ajuda os alunos a praticar a habilidade de acessar
elementos em tuplas e também a familiarizá-los com o conceito de fatiamento
de tuplas.
"""

produto = ('Laptop', 10, 1500.00)

print(f'Nome: {produto[0]}')
print(f'Quantidade: {produto[1]}')

print(f'Fatiamento: {produto[:2]}')

print()

nome = produto[0]
print(f'O nome do produto é: {nome}')

quantidade = produto[1]
print(f'A quantidade deste produto em estoque: {quantidade}')

info_disponiveis = produto[:2]
print(f'As informações disponíveis do produto: {info_disponiveis}')
# Out:
# Nome: Laptop
# Quantidade: 10
# Fatiamento: ('Laptop', 10)
#
# O nome do produto é: Laptop
# A quantidade deste produto em estoque: 10
# As informações disponíveis do produto: ('Laptop', 10)

# %%
"""
Imutabilidade:
   
"""

"""
Exemplo Prático: Restrições de Segurança no Aeroporto

Contexto: Em um sistema de aeroporto, você deseja armazenar regras de
segurança em relação à bagagem de mão dos passageiros.

Algumas regras são imutáveis (como dimensões da bagagem), enquanto outras,
como os itens proibidos, podem ser atualizados periodicamente.
"""

#1. Tentativas de alterar um elemento de uma tupla resultarão em um erro:

dimensoes_bagagem = (55, 35, 25)

#2. Mas se um elemento da tupla for mutável, como uma lista, você pode
#   modificar esse elemento.

itens_proibidos = ['liquidos acima de 100ml', 'objetos cortantes', 
                  'material explosivo']
regras_bagagem = (dimensoes_bagagem, itens_proibidos)

regras_bagagem[1].append('baterias de lítio')
print(regras_bagagem[1])
# Out:
# ['liquidos acima de 100ml', 'objetos cortantes', 'material explosivo', 'baterias de lítio']

# %%
"""
Exercício: Gerenciamento Vendas de Produtos

Contexto: Você é um gerente de vendas em uma loja de eletrônicos. Cada
produto vendido é registrado em uma tupla que contém o nome do produto,
seu preço fixo e uma lista das vendas realizadas durante o mês (
quantidades vendidas a cada dia).

Objetivo: Entenda a imutabilidade das tuplas enquanto gerencia o registro
de vendas diárias de um produto específico.

Instruções:

    Registro de Produto:
    
        Crie uma tupla chamada produto com as seguintes informações:
        'Smartphone', 1000.00 (preço em dólares),
        [2, 3, 4] (vendas nos três primeiros dias do mês).
        
    Tentativa de Alteração de Imutabilidade:
        Tente alterar o preço do 'Smartphone' para 1100.00.
        Observe o erro gerado e explique por que ele ocorre.
        
    Atualização de Vendas:
        Um novo lote de 'Smartphone' foi vendido e você vendeu mais 5
        unidades no quarto dia. Adicione esse número à lista de vendas.
        
        Exiba a lista de vendas atualizada para o 'Smartphone'.
        
Questões:

a) Ao tentar alterar o preço do 'Smartphone', qual erro você encontrou?

b) Qual é o registro de vendas atualizado após adicionar as vendas do quarto
dia?

Este exercício visa ensinar sobre a imutabilidade das tuplas em um contexto
prático de vendas. Ao tentar modificar o preço, enfrentarão um erro e,
assim, compreenderá a natureza imutável das tuplas. No entando, ao atualizar
o registro de vendas, que é uma lista mutável dentro da tupla, aprenderá
sobre a capacidade de modificar elementos mutáveis mesmo dentro de estruturas
imutáveis.
"""

# 1. 
produto = ('Smartphone', 1000.00, [2, 3, 4])
print(produto)
print()

# 2. Tupla não pode ser modificada.
# produto[0] = 'Samsung'
# print(produto)
#TypeError: 'tuple' object does not support item assignment
#(Não aceita atribuição de ítens)

# Lista pode ser modificada, mesmo dentro de uma tupla.
# Cada grupo tem suas leis dentro do seu "universo particular"

produto[2].append(5) # Adiciona o número 5 à lista
print(produto)
print()

# a) TypeError
#produto[0] = 'Samsung'

# b)
print(f'O registo de vendas após o 4 dia é: {produto[2]}')
# Out:
# ('Smartphone', 1000.0, [2, 3, 4])
#
# ('Smartphone', 1000.0, [2, 3, 4, 5])
#
# O registo de vendas após o 4 dia é: [2, 3, 4, 5]

# %%
"""
Operações com Tuplas
    Concatenação: (1, 2) + (3, 4)
    Repetição: (1, 2) * 3
    Verificar se um elemento está na tupla: 2 in (1, 2, 3)
"""

"""
Exemplo Prático: Planejamento de Viagem

Contexto: Imagine que você está planejando uma viagem por várias cidades.
As cidades são representadas por números, e você deseja organizar a 
ordem das visitas, verificar cidades repetidas
, e ver se visitou uma cidade específica.
"""

#1. Concatenação de Tuplas - Adicionando destinos à sua viagem

primeiras_cidades = (1, 2)
proximas_cidades = (3, 4)

roteiro_viagem = primeiras_cidades + proximas_cidades
print(roteiro_viagem)

#2. Repetição - Visitando algumas cidades mais de uma vez

cidades_favoritas = (1, 2)

roteiro_repetido = cidades_favoritas * 3
print(roteiro_repetido)

#3. Verificar se uma cidade está em seu roteiro

roteiro_total = (1, 2, 3, 4, 1, 2, 1, 2)

cidade_inclusa = 2 in roteiro_total

print(cidade_inclusa)
# Out:
# (1, 2, 3, 4)
# (1, 2, 1, 2, 1, 2)
# True

# %%
"""
Exercício: Manipulando Sequência de Números

Contexto: Você está trabalhando com sequências de números em um software
de análise. Para isso, você utiliza tuplas, uma vez que as sequências
são fixas e não precisam de alterações. Contudo, existem algumas operações
com as sequências que você precisa realizar para obter novos conjuntos 
de dados.

Objetivo: Utilize operações com tuplas para manipular e analisar 
sequências de números.

Instruções:

    Concatenação de Sequências:
        Você possui duas sequências: A = (1, 2) e B = (3, 4)
        Crie uma nova sequência C combinando as sequências A e B.
        
    Repetição de Sequências:
        Suponha que você queira repetir a sequência A três vezes para
        criar uma nova sequência D.
        Faça essa operação e registre o resultado em D.
        
    Análise de Elemento em Sequência:
        Utilizando a sequência E = (1, 2, 3, 4, 1, 2, 1, 2), verifique 
        se o número 2 está presente.
        
Questões:

a) Qual é a sequência resultante C após a concatenação?

b) Qual é a sequência D após repetir a sequência A três vezes?

c) O número 2 está presente na sequência E?
"""

# 1. Concatenação
A = (1, 2)
print(f'A = {A}')

B = (3, 4)
print(f'B = {B}')

C = A + B
print(f'C = {C}')

#==================================================#

# 2. Repetição
D = A * 3
print(f'D = {D}')

print()

#==================================================#

E = (1, 2, 3, 4, 1, 2, 1, 2)
print(2 in E)

print()

#==================================================#
print(f'Qual é a sequência resultante C após a concatenação?: {C}')

print(f'Qual é a sequência D após repetir a sequência A três vezes?: {D}')

print(f'O número 2 está presente na sequência E?: {E}')
# Out:
# A = (1, 2)
# B = (3, 4)
# C = (1, 2, 3, 4)
# D = (1, 2, 1, 2, 1, 2)
#
# True
#
# Qual é a sequência resultante C após a concatenação?: (1, 2, 3, 4)
# Qual é a sequência D após repetir a sequência A três vezes?: (1, 2, 1, 2, 1, 2)
# O número 2 está presente na sequência E?: (1, 2, 3, 4, 1, 2, 1, 2)

# %%
"""
Métodos de Tuplas:
    count(): conta o número de vezes que um elemento aparece na tupla.
    index(): retorna o índice do primeiro elemento que corresponde ao valor
    especificado.
"""

"""
Exemplo Prático: Gerenciamento de Vendas de Produtos

Concexto: Imagine que você é um gerente em uma loja de eletrônicos e deseja
analisar as vendas dos produtos ao longo da semana. Cada produto vendido
é representado por um código numérico.
"""

#1. Uso do método count():

vendas = (101, 102, 103, 101, 102, 101, 104)
vendas_produto_101 = vendas.count(101)
print(f"O produto 101 foi vendido {vendas_produto_101} vezes.")

#Uso do método index():
vendas = (101, 102, 103, 101, 102, 101, 104)
primeiro_dia_venda_103 = vendas.index(103) + 1
print(f'O produto 103 foi vendido pela primeira vez no '
      f'{primeiro_dia_venda_103} dia da semana.')
# Out:
# O produto 101 foi vendido 3 vezes.
# O produto 103 foi vendido pela primeira vez no 3 dia da semana.

# %%
"""
Exercício: Análise de Avaliações de Filmes

Contexto: Você é um analista em uma plataforma de streaming e recebeu
uma lista de avaliações de um filme recém-lançado. As avaliações são
dadas como estrelas, variando de 1 a 5. Você deve analisar essas
avaliações para fornecer insights sobre a recepção do filme.

Dados fornecidos: avaliacoes = (5, 4, 4, 3, 5, 2, 4, 3, 5, 5, 1, 4, 3, 5, 2)

Objetivo: Use os métodos de tupla para responder às seguintes perguntas:

    Quantidade de Avaliações de 5 estrelas:
        Quantas vezes o filme foi avaliado com 5 estrelas?
    Primeira Avaliação de 1 estrela:
        Em que posição da sequência aparece a primeira avaliação de 1 estrela?
        
Instruções:

a) Utilize o método count() para determinar o número de avaliações de 5
estrelas na tupla avaliacoes.

b) Utilize o método index() para encontrar a posição da primeira
avaliação de 1 estrela na tupla avaliacoes.


"""
# Questões:

# a) Quantas avaliações de 5 estrelas o filme recebeu?

avaliacoes = (5, 4, 4, 3, 5, 2, 4, 3, 5, 5, 1, 4, 3, 5, 2)

quantidade_5_avaliacoes = avaliacoes.count(5)

print(f'a) Quantas avaliações de 5 estrelas o filme recebeu?: '
      f'{quantidade_5_avaliacoes}')

# b) Qual é a posição da primeira avaliação de 1 estrela?

posicao_primeira_1_estrela = avaliacoes.index(1) + 1
print(f'b) Qual é a posição da primeira avaliação de 1 estrela?: '
      f'{posicao_primeira_1_estrela}')
# Out:
# a) Quantas avaliações de 5 estrelas o filme recebeu?: 5
# b) Qual é a posição da primeira avaliação de 1 estrela?: 11

# %%
"""
Desempacotamento de Tuplas:
    Atribuindo valores de uma tupla a múltiplas variáveis:
    a, b, c = (1, 2, 3)
    
"""

"""
Exemplo Prático: Gestão de Estudantes

Contexto: Imagine que voce é um professor e recebe informações de um estudante
em forme de tupla. Essa tupla contém o nome do estudante, sua idade
e sua nota média.

Para facilitar o acesso a esses dados, voce pode desempacotar a tupla em
variáveis individuais.
"""

# Exemplo:

# 1. Dados fornecidos

estudante_info = ('João', 20, 85.5)

# Desempacotamento

nome, idade, nota_media = estudante_info
print(f'Nome do estudante: {nome}')
print(f'Idade: {idade}')
print(f'Nota média: {nota_media}')
# Out:
# Nome do estudante: João
# Idade: 20
# Nota média: 85.5

# %%
"""
Exercício: Gestão de pacotes de viagem

Contexto: voce trabalha em uma agencia de turismo e tem pacotes de viagem
que são representados como tuplas. Cada pacote contém o destino, o 
número de noites e o preço. Para facilitar o processamento desses
pacotes, voce precisa desempacotar os detalhes em variáveis individuais.

Dados fornecidos:

Considere o seguinte pacote de viagem: pacote_viagem = ('Paris', 5, 1500),
onde:
    'Paris' é o destino da viagem.
    5 é o número de noites.
    1500 é o preço do pacote em dólares.
    
Objetivo: Desempacote os detalhes do pacote de viagem em variáveis
individuais e imprima as informações

Instruções:

    Atribua os valores da tupla pacote_viagem a tres variáveis: destino,
    noites e preço.
    Imprima o destino, o número de noites e o preço do pacote.
    
Questões:

a) Qual é o destino do pacote de viagem?
b) Por quantas noites é o pacote?
c) Qual é o preço do pacote?
"""

pacote_viagem = ('Paris', 5, 1500)

destino, noites, preco = pacote_viagem

print(f'a) Destino: {destino}')

print(f'b) Número de Noites: {noites} noites.')

print(f'c) Preço: ${preco:.2f}. ')
# Out:
# a) Destino: Paris
# b) Número de Noites: 5 noites.
# c) Preço: $1500.00.

# %%
"""
Aplicações Práticas:
    Retornando múltiplos valores de uma função usando tuplas.
    Uso de tuplas em loops for: for a, b in [(1, 2), (3, 4)]:
    Trocando valores entre duas variáveis: a, b = b, a
"""

"""
Exemplo prático: Analisando vendas

Contexto: Você é um analista em uma loja e precisa acompanhar as vendas 
diárias de dois produtos: A e B. Seu objetivo é calcular o total vendido
e o produto mais vendido no dia.
"""

# 1. Retornando múltiplos valores de uma função usando tuplas

# Você quer criar uma função que retorna o total vendido e o produto
# mais vendido do dia.
def analisar_vendas(vendas_A, vendas_B):
    
    total_vendido = vendas_A + vendas_B
    mais_vendido = 'A' if vendas_A > vendas_B else 'B'
    return total_vendido, mais_vendido

total, top_produto = analisar_vendas(100, 85)
print(f'Total Vendido: {total}')
print(f'Produto mais vendido: {top_produto}')

# 2. Uso de tuplas em loops for

vendas = [(100, 90), (100, 115), (105, 100)]

for vendas_A, vendas_B in vendas:
    print(f'Vendas de A: {vendas_A}, Vendas de B: {vendas_B}')
    
print()

# 3. Trocando valores entre duas variáveis

vendas_A = 100
vendas_B = 85
vendas_A, vendas_B = vendas_B, vendas_A

print(f'Vendas Corrigidas - A: {vendas_A}, B: {vendas_B}')
# Out:
# Total Vendido: 185
# Produto mais vendido: A
# Vendas de A: 100, Vendas de B: 90
# Vendas de A: 100, Vendas de B: 115
# Vendas de A: 105, Vendas de B: 100
#
# Vendas Corrigidas - A: 85, B: 100

# %%
"""
Exercício: Gerenciamento de Estoque

Conexto: Você trabalha no controle de estoque de uma empresa de eletrônicos.
A empresa vende dois produtos populares: smartphones e smartwatches.

Diariamente, você precisa calcular o total de produtos vendidos, identificar
qual produto foi mais vendido e reorganizar os números caso haja algum
erro nas entradas.

Instruções:

    1. Retornando múltiplos valores de uma função usando tuplas.
        -Crie uma função chamada resumo_vendas que aceite dois 
        argumentos: vendas_smartphones e vendas_smartwatches.
        
    2. Uso de tuplas em loops for.
        - Dada a lista vendas_semana = [(70, 65), (80, 82), (90, 88)]
        
        - Use um loop for para imprimir as vendas de smartphones e
        smartwatches para cada dia?
        
    3. Trocando valores entre duas variáveis.
        -Suponha que voce cometeu um erro e registrou as vendas de segunda-feira
        de forma invertida: vendas_segunda = (65, 70), onde o primeiro valor e
        para smartwatches e o segundo para smartphones.
        
        -Corrija essa entrada invertendo os valores.
        - Pergunta: Qual é a entrada corrigida para as vezes de segunda-feira?
        
"""

# Solução:

# 1. Retornando múltiplos valores de uma função usando tuplas.

def resumo_vendas(vendas_smartphones, vendas_smartwatches):
    
    total_vendas = vendas_smartphones + vendas_smartwatches
    mais_vendido = 'smartphone' if vendas_smartphones > vendas_smartwatches else 'Smartwatch'
    
    return total_vendas, mais_vendido

total, top_produto = resumo_vendas(80, 70)

print(f'Total de Vendas: {total}')
print(f'Produto Mais Vendido: {top_produto}')

print()

# 2. Uso de tuplas em loops for.

vendas_semana = [(70, 65), (80, 82), (90, 88)]

for smartphones, smartwatches in vendas_semana:
    print(f'Vendas de A: {smartphones}, Vendas de B: {smartwatches}')
    
print()

# 3. Trocando valores entre duas variáveis

vendas_segunda = (65, 70)

vendas_segunda = vendas_segunda[::-1]

print(f'Vendas corrigidas de segunda-feira - '
      f'Smartphones: {vendas_segunda[0]}, '
      f'Smartwatches: {vendas_segunda[1]}')
# Out:
# Total de Vendas: 150
# Produto Mais Vendido: smartphone
#
# Vendas de A: 70, Vendas de B: 65
# Vendas de A: 80, Vendas de B: 82
# Vendas de A: 90, Vendas de B: 88
#
# Vendas corrigidas de segunda-feira - Smartphones: 70, Smartwatches: 65

# %%
"""
Comparando Tuplas:
    Tuplas podem ser comparadas usando operadores de comparação: 
    (1, 2) < (1, 3)
"""

"""
Exemplo Prático: Comparando Tuplas

No Python, quando duas tuplas são comparadas, a comparação é realizada
elemento por elemento, começando pelo primeiro. Assim que um par de
elementos é encontrado onde um é menor (ou maior) que o outro, a comparação
retorna True ou False e não prossegue para os próximos elementos.

Se todos os elementos comparados forem iguais e uma das tuplas for mais
curta que a outra, a tupla mais curta é considerada menor.

Aqui estão alguns exemplos para ilustrar isso:
"""

# 1. Comparando o Primeiro Elemento:
t1 = (1, 2)
t2 = (1, 3)
print(t1 < t2)

# 2. Ignorando Elementos Iguais:
t1 = (1, 2, 3)
t2 = (1, 2, 4)
print(t1 < t2)

# 3. Comparando Tuplas de Diferentes Tamanhos:
t1 = (1, 2)
t2 = (1, 2, 3)
print(t1 < t2)

# 4. Comparação de Elementos de Diferentes Tipos:
t1 = (1, 'apple')
t2 = (2, 'banana')
print(t1 < t2)
# Out:
# True
# True
# True
# True
# True

# %%
"""
Exercício: Comparação de Tuplas

Dadas as seguintes tuplas:

Responda as seguintes questões:

"""
t1 = (3, 5)
t2 = (3, 4, 10)
t3 = (3, 6)
t4 = (2, 100)
t5 = (3, 5)

print('t1 = (3, 5)')
print('t2 = (3, 4, 10)')
print('t3 = (3, 6)')
print('t4 = (2, 100)')
print('t5 = (3, 5)')

print()

# 1. Qual é maior: t1 ou t2?

print('1. Qual é maior: t1 ou t2?')
if t1 > t2:
    print(f't1 é maior: {t1}')
else:
    print(f't2 é maior: {t2}')

print()

# 2. t3 é maior que t1?

print('2. t3 é maior que t1?')
if t3 > t1:
    print(f"t3 é maior: {t3}")
else:
    print(f't1 é maior: {t1}')

print()

# 3. Compare t4 e t1. Qual é menor?
print('3. Compare t4 e t1. Qual é menor?')
if t4 < t1:
    print(f't4 é menor: {t4}')
else:
    print(f't1 é menor: {t1}')

print()

# 4. t1 e t5 são iguais?
r4 = t1 == t5

print(f"4. t1 e t5 são iguais? {r4}")
# Out:
# t1 = (3, 5)
# t2 = (3, 4, 10)
# t3 = (3, 6)
# t4 = (2, 100)
# t5 = (3, 5)
#
# 1. Qual é maior: t1 ou t2?
# t1 é maior: (3, 5)
#
# 2. t3 é maior que t1?
# t3 é maior: (3, 6)
#
# 3. Compare t4 e t1. Qual é menor?
# t4 é menor: (2, 100)
#
# 4. t1 e t5 são iguais? True

# %%
"""
Diferenças entre Listas e Tuplas:

    Quando e por que usar uma em vez da outra
"""

"""
Exemplo Prático sobre Diferenças entre Listas e Tuplas:

Imagine que você é um desenvolvedor de software trabalhando em um sistema
de gerenciamento para uma biblioteca. O sistema mantém um registro de
todos os livros disponíveis na biblioteca. Cada livro tem atributos 
como título, autor, ISBN, ano de publicação, etc.
"""

# 1. Listas:

livros_mais_emprestados = ['O Pequeno Príncipe', '1984', 'Dom Quixote']

print(livros_mais_emprestados)

print()

livros_mais_emprestados.append('O Senhor dos Anéis')

print(livros_mais_emprestados)

#==========================================#

# 2. Tuplas:

livro_info = ('O Pequeno Príncipe')
# Out:
# ['O Pequeno Príncipe', '1984', 'Dom Quixote']
#
# ['O Pequeno Príncipe', '1984', 'Dom Quixote', 'O Senhor dos Anéis']

# %%
"""
Exercício: Diferenças entre Listas e Tuplas

Contexto:
Você é o arquiteto de software de uma startup de turismo. Seu software
precisa lidar com informações sobre destinos turísticos e os feedbacks
dos usuários sobre esses destinos.

Tarefas:

    1. Destinos Turísticos:
    Cada destino turístico tem informações fixas como nome, país, e um
    código identificador único. Essas informações não mudam uma vez 
    que o destino é adicionado ao sistema.
    
        Crie uma representação adequada para um destino turístico no sistema.
    
    2. Feedbacks dos Usuários:
    Os usuários do sistema podem adicionar feedbacks sobre os destinos
    visitados. Estes feedbacks são dinânmicos, já que os usuários podem
    adicionar, editar ou deletar seus comentários.
    
        Crie uma representação adequada para armazenar feedbacks de um destino
        turístico.
        
    3. Análise:
        Explique por que você escolheu a estrutura de dados espedífica (lista
        ou tupla) para cada um dos casos acima.
        
        Dê um exemplo de uma situação em que seria desvantajoso usar a 
        estrutura de dados oposta em cada um dos casos.
"""

destino_turistico = ('Torre Eiffel', 'França', 'FR-001')

print(f'Destino: {destino_turistico}.')

print()

feedback_torre_eiffel = [
    "Maravilhoso!",
    "A vista é espetacular.",
    "Muito lotado durante a alta temporada."
]

print(f'{feedback_torre_eiffel}')

print()

# Para adicionar um novo feedback:
feedback_torre_eiffel.append('Recomendo visitar à noite.')

print(feedback_torre_eiffel)
# Out:
# Destino: ('Torre Eiffel', 'França', 'FR-001').
#
# ['Maravilhoso!', 'A vista é espetacular.', 'Muito lotado durante a alta temporada.']
#
# ['Maravilhoso!', 'A vista é espetacular.', 'Muito lotado durante a alta temporada.', 'Recomendo visitar à noite.']
